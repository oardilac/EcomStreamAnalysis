# %%
from pyspark.sql.functions import from_json, col, to_timestamp
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
from pyspark.sql import SparkSession

# %%
def write_to_cassandra(target_df, batch_id):
    target_df.write \
        .format("org.apache.spark.sql.cassandra") \
        .option("keyspace", "spark_db") \
        .option("table", "customer_search") \
        .mode("append") \
        .save()
    target_df.show()

# %%
spark = SparkSession \
        .builder \
        .master("local[3]") \
        .appName("Stream Table Join Demo") \
        .config("spark.streaming.stopGracefullyOnShutdown", "true") \
        .config("spark.sql.shuffle.partitions", 2) \
        .config("spark.cassandra.connection.host", "localhost") \
        .config("spark.cassandra.connection.port", "9042") \
        .config("spark.sql.extensions", "com.datastax.spark.connector.CassandraSparkExtensions") \
        .config("spark.sql.catalog.lh", "com.datastax.spark.connector.datasource.CassandraCatalog") \
        .getOrCreate()

# %%
search_schema = StructType([
        StructField("id", StringType()),
        StructField("customer_id", StringType()),
        StructField("customer_name", StringType()),
        StructField("product_searched", StringType()),
        StructField("search_date", StringType()),
        StructField("country_name", StringType()),
        StructField("state", StringType())
    ])

# %%
kafka_source_df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", "localhost:9092") \
        .option("subscribe", "product-customer-qty") \
        .option("startingOffsets", "earliest") \
        .option("failOnDataLoss", False) \
        .load()

# %%
value_df = kafka_source_df.select(from_json(col("value").cast("string"), search_schema).alias("value"))

# %%
prod_customer_df = value_df.select("value.*") \
        .withColumn("search_date", to_timestamp(col("search_date"), "yyyy-MM-dd HH:mm:ss"))

# %%
prod_customer_df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- product_searched: string (nullable = true)
#  |-- search_date: timestamp (nullable = true)
#  |-- country_name: string (nullable = true)
#  |-- state: string (nullable = true)

# %%
output_df = prod_customer_df.select(col("id"), col("customer_id"), col("customer_name"), col("product_searched"), 
                             col("search_date"), col("country_name"),col("state"))
#                             .withColumn("idNum", col("customer_id").cast(IntegerType())) \
#                             .withColumn("id",    col("id").cast(IntegerType()))

# %%
# #to view the data in the console
notification_writer_query = output_df.writeStream \
        .format("console") \
        .outputMode("append") \
        .option("truncate", "false") \
        .option("checkpointLocation", "./checkpoints/cassandra-proj/") \
        .start()

# # notification_writer_query.awaitTermination()

# %%
#Aggregations Val

# agg_output_df = output_df.groupBy("country_name", "product_searched")\
#       .agg(count("id")).alias("search_qty")

# agg_search_locations_df = output_df.groupBy("name")\
#      .agg(sum("idNum"), count("id"))

# %%
# output_query = output_df.writeStream \
output_query = output_df.writeStream \
        .foreachBatch(write_to_cassandra) \
        .outputMode("update") \
        .option("checkpointLocation", "./checkpoints/cassandra-proj") \
        .trigger(processingTime="1 minute") \
        .start()

# %%
output_query.awaitTermination()
# Out:
# +---+-----------+-------------+----------------+-------------------+--------------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|        country_name|               state|
# +---+-----------+-------------+----------------+-------------------+--------------------+--------------------+
# |233|         17|       Marcia| Ninja Air Frier|2023-04-28 22:11:12|         Philippines|      South Cotabato|
# |234|          5|        Maria| Apple Iphone 14|2023-04-28 22:11:42|Saint Kitts And N...|Saint John Capist...|
# +---+-----------+-------------+----------------+-------------------+--------------------+--------------------+
#
# +---+-----------+-------------+------------------+-------------------+--------------------+------------------+
# | id|customer_id|customer_name|  product_searched|        search_date|        country_name|             state|
# +---+-----------+-------------+------------------+-------------------+--------------------+------------------+
# |235|          2|     Marielys|Samsung Galaxy s22|2023-04-28 22:12:12|Palestinian Terri...|             Rafah|
# |236|          5|        Maria|        Air Jordan|2023-04-28 22:12:42|          Montenegro|Kotor Municipality|
# +---+-----------+-------------+------------------+-------------------+--------------------+------------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# |237|         11|       Emilia|           Bed Sheet|2023-04-28 22:13:12|       Benin|  Mono Department|
# |238|          8|      Maryina|Workout Leggins f...|2023-04-28 22:13:42|     Moldova|Criuleni District|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# |239|          6|       Emilio|      Air Jordan|2023-04-28 22:14:12|     Albania|      Kukës District|
# |240|          7|         Emil|            Roku|2023-04-28 22:14:42|    Maldives|South Central Pro...|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# |241|          7|         Emil|                Roku|2023-04-28 22:15:12|  Azerbaijan|Yardymli District|
# |242|         16|       Marius|Gildan Mens Assor...|2023-04-28 22:15:42|     Ecuador|          Pastaza|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+------------------+-------------------+-------------------+-------------------+
# | id|customer_id|customer_name|  product_searched|        search_date|       country_name|              state|
# +---+-----------+-------------+------------------+-------------------+-------------------+-------------------+
# |243|         14|       Mirtha|Samsung Galaxy s22|2023-04-28 22:16:12|            Ukraine|   Cherkaska oblast|
# |244|         11|       Emilia|   Ninja Air Frier|2023-04-28 22:16:42|Antigua And Barbuda|Saint George Parish|
# +---+-----------+-------------+------------------+-------------------+-------------------+-------------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|         state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------+
# |245|          3|      EmilyAn|          Air Jordan|2023-04-28 22:17:12|      Turkey|      Osmaniye|
# |246|         13|        Mario|Workout Leggins f...|2023-04-28 22:17:42|     Namibia|Omusati Region|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|         state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# |247|         19|    Johnathan|     Samsung Tab|2023-04-28 22:18:12|      Mexico|        Oaxaca|
# |248|          5|        Maria| Ninja Air Frier|2023-04-28 22:18:42|       Nepal|Western Region|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# |249|          2|     Marielys|Gildan Mens Assor...|2023-04-28 22:19:12|       Italy|    Vibo Valentia|
# |250|          6|       Emilio|Gildan Mens Assor...|2023-04-28 22:19:42|  Azerbaijan|Khachmaz District|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|         state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# |251|          4|         John|     Samsung Tab|2023-04-28 22:20:12|       Italy|Emilia-Romagna|
# |252|          2|     Marielys|      Apple Ipad|2023-04-28 22:20:42|    Cambodia|  Kampong Speu|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
#
# +---+-----------+-------------+--------------------+-------------------+--------------+--------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|  country_name|               state|
# +---+-----------+-------------+--------------------+-------------------+--------------+--------------------+
# |253|         20|     JohnEric|Workout Leggins f...|2023-04-28 22:21:12|Czech Republic|      Jihočeský kraj|
# |254|         12|       Jowell|Samsung Galaxy s2...|2023-04-28 22:21:42|        Latvia|Mālpils Municipality|
# +---+-----------+-------------+--------------------+-------------------+--------------+--------------------+
#
# +---+-----------+-------------+------------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+------------------+-------------------+------------+-----------------+
# |255|         10|        Emona|              Roku|2023-04-28 22:22:12|    Malaysia|     Kuala Lumpur|
# |256|         14|       Mirtha|Samsung Galaxy s22|2023-04-28 22:22:42|     Albania|Tepelenë District|
# +---+-----------+-------------+------------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# |257|         17|       Marcia|Workout Leggins f...|2023-04-28 22:23:12|Fiji Islands|    Central Division|
# |258|         13|        Mario|  Asus Gaming Laptop|2023-04-28 22:23:42|    Slovenia|Šentrupert Munici...|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|              state|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# |259|          2|     Marielys|            Creatine|2023-04-28 22:24:12|    Slovenia|Vojnik Municipality|
# |260|         11|       Emilia|Samsung Galaxy s2...|2023-04-28 22:24:42| Puerto Rico|      Trujillo Alto|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# +---+-----------+-------------+--------------------+-------------------+------------+---------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|          state|
# +---+-----------+-------------+--------------------+-------------------+------------+---------------+
# |261|          5|        Maria|Samsung Galaxy s2...|2023-04-28 22:25:12|    Bulgaria|Pernik Province|
# |262|         13|        Mario|  Asus Gaming Laptop|2023-04-28 22:25:42|       Niger|  Maradi Region|
# +---+-----------+-------------+--------------------+-------------------+------------+---------------+
#
# +---+-----------+-------------+------------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+------------------+-------------------+------------+--------------------+
# |263|         12|       Jowell|Asus Gaming Laptop|2023-04-28 22:26:12|  Seychelles|        Les Mamelles|
# |264|         18|       Johvay|        Air Jordan|2023-04-28 22:26:42|    Paraguay|Alto Paraguay Dep...|
# +---+-----------+-------------+------------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# |265|         18|       Johvay|      Air Jordan|2023-04-28 22:27:12|  Cape Verde|Ribeira Brava Mun...|
# |266|         13|        Mario|      Air Jordan|2023-04-28 22:27:42|     Romania|       Vâlcea County|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+--------------------+-------------------+--------------+-----------+
# | id|customer_id|customer_name|    product_searched|        search_date|  country_name|      state|
# +---+-----------+-------------+--------------------+-------------------+--------------+-----------+
# |267|         20|     JohnEric|Workout Leggins f...|2023-04-28 22:28:12|      Barbados|Saint James|
# |268|         15|       Martha|Workout Leggins f...|2023-04-28 22:28:42|Czech Republic|      Louny|
# +---+-----------+-------------+--------------------+-------------------+--------------+-----------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# |269|         16|       Marius|           Bed Sheet|2023-04-28 22:29:12|      Mexico|Veracruz de Ignac...|
# |270|         19|    Johnathan|Workout Leggins f...|2023-04-28 22:29:42|      Uganda|      Ngora District|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+------------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+------------------+-------------------+------------+-----------------+
# |271|         14|       Mirtha|Asus Gaming Laptop|2023-04-28 22:30:12| Switzerland|           Aargau|
# |272|          1|       Johnny|Asus Gaming Laptop|2023-04-28 22:30:42|  Azerbaijan|Shamakhi District|
# +---+-----------+-------------+------------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+----------------+-------------------+--------------------+-----------------+
# | id|customer_id|customer_name|product_searched|        search_date|        country_name|            state|
# +---+-----------+-------------+----------------+-------------------+--------------------+-----------------+
# |273|         14|       Mirtha|     Water Shoes|2023-04-28 22:31:12|Sao Tome and Prin...|Príncipe Province|
# |274|          1|       Johnny|     Water Shoes|2023-04-28 22:31:42|Cote D'Ivoire (Iv...|     Yamoussoukro|
# +---+-----------+-------------+----------------+-------------------+--------------------+-----------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# |275|         20|     JohnEric|Workout Leggins f...|2023-04-28 22:32:12| Saint Lucia|Soufrière Quarter|
# |276|         11|       Emilia|            Creatine|2023-04-28 22:32:42|   Indonesia|      Jawa Tengah|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+------------------+-------------------+------------+------------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|       state|
# +---+-----------+-------------+------------------+-------------------+------------+------------+
# |277|          6|       Emilio|Asus Gaming Laptop|2023-04-28 22:33:12|     Tunisia|       Gafsa|
# |278|          2|     Marielys|        Fire Stick|2023-04-28 22:33:42|Burkina Faso|Bam Province|
# +---+-----------+-------------+------------------+-------------------+------------+------------+
#
# +---+-----------+-------------+------------------+-------------------+------------+-------------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|        state|
# +---+-----------+-------------+------------------+-------------------+------------+-------------+
# |279|          5|        Maria|          Creatine|2023-04-28 22:34:12|    Portugal|        Braga|
# |280|          9|          Jox|Asus Gaming Laptop|2023-04-28 22:34:42|     Belgium|East Flanders|
# +---+-----------+-------------+------------------+-------------------+------------+-------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|        state|
# +---+-----------+-------------+----------------+-------------------+------------+-------------+
# |281|         19|    Johnathan| Apple Iphone 14|2023-04-28 22:35:12|        null|         null|
# |282|         15|       Martha|     Bed Pillows|2023-04-28 22:35:42|   Lithuania|Kaunas County|
# +---+-----------+-------------+----------------+-------------------+------------+-------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# |283|          9|          Jox|        Creatine|2023-04-28 22:36:12|  Cape Verde|Sotavento Islands|
# |284|         13|        Mario|      Fire Stick|2023-04-28 22:36:42|        Chad|        Wadi Fira|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+----------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|           state|
# +---+-----------+-------------+--------------------+-------------------+------------+----------------+
# |285|         17|       Marcia|         Samsung Tab|2023-04-28 22:37:12|   Indonesia|Kalimantan Timur|
# |286|          9|          Jox|Workout Leggins f...|2023-04-28 22:37:42|    Tanzania|  Zanzibar North|
# +---+-----------+-------------+--------------------+-------------------+------------+----------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# |287|          5|        Maria|     Bed Pillows|2023-04-28 22:38:12|       Malta|               Nadur|
# |288|         18|       Johvay| Ninja Air Frier|2023-04-28 22:38:42|  Luxembourg|Canton of Esch-su...|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# |289|          1|       Johnny|            Roku|2023-04-28 22:39:12|     Eritrea|Gash-Barka Region|
# |290|          3|      EmilyAn|        Creatine|2023-04-28 22:39:42|      Mexico|           Sonora|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+--------------------+-------------------+--------------+------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|  country_name|             state|
# +---+-----------+-------------+--------------------+-------------------+--------------+------------------+
# |291|         18|       Johvay|Workout Leggins f...|2023-04-28 22:40:12|United Kingdom|Derry City Council|
# |292|         12|       Jowell|Samsung Galaxy s2...|2023-04-28 22:40:42|         Malta|            Għasri|
# +---+-----------+-------------+--------------------+-------------------+--------------+------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# |293|          1|       Johnny|     Samsung Tab|2023-04-28 22:41:12|      Mexico|Veracruz de Ignac...|
# |294|         19|    Johnathan| Ninja Air Frier|2023-04-28 22:41:42|       Spain|         Ciudad Real|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# |295|          8|      Maryina|     Apple Iphone 14|2023-04-28 22:42:12|   Sri Lanka|Sabaragamuwa Prov...|
# |296|         14|       Mirtha|Samsung Galaxy s2...|2023-04-28 22:42:42|      Panama| Los Santos Province|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|         state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# |297|         13|        Mario|            Roku|2023-04-28 22:43:12|       China|  Heilongjiang|
# |298|         18|       Johvay| Ninja Air Frier|2023-04-28 22:43:42|     Jamaica|Hanover Parish|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|              state|
# +---+-----------+-------------+----------------+-------------------+------------+-------------------+
# |299|         13|        Mario|      Fire Stick|2023-04-28 22:44:12|  Mauritania|             Tagant|
# |300|          8|      Maryina|        Creatine|2023-04-28 22:44:42|        Oman|Ash Sharqiyah South|
# +---+-----------+-------------+----------------+-------------------+------------+-------------------+
#
# +---+-----------+-------------+--------------------+-------------------+---------------+-------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|   country_name|              state|
# +---+-----------+-------------+--------------------+-------------------+---------------+-------------------+
# |301|         13|        Mario|Samsung Galaxy s2...|2023-04-28 22:45:12|          Kenya|            Turkana|
# |302|         11|       Emilia|         Water Shoes|2023-04-28 22:45:42|North Macedonia|Prilep Municipality|
# +---+-----------+-------------+--------------------+-------------------+---------------+-------------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|              state|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# |303|         20|     JohnEric|Workout Leggins f...|2023-04-28 22:46:12|       India|             Ladakh|
# |304|          5|        Maria|          Apple Ipad|2023-04-28 22:46:42|      Latvia|Lubāna Municipality|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
#
# +---+-----------+-------------+----------------+-------------------+--------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|  country_name|               state|
# +---+-----------+-------------+----------------+-------------------+--------------+--------------------+
# |305|          5|        Maria| Apple Iphone 14|2023-04-28 22:47:12|       Ecuador|              El Oro|
# |306|         17|       Marcia|     Bed Pillows|2023-04-28 22:47:42|United Kingdom|London Borough of...|
# +---+-----------+-------------+----------------+-------------------+--------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|   state|
# +---+-----------+-------------+----------------+-------------------+------------+--------+
# |307|          9|          Jox|      Air Jordan|2023-04-28 22:48:13|      France|Yvelines|
# |308|         15|       Martha| Ninja Air Frier|2023-04-28 22:48:43|        null|    null|
# +---+-----------+-------------+----------------+-------------------+------------+--------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# |309|          6|       Emilio|Workout Leggins f...|2023-04-28 22:49:13|   Indonesia|Sulawesi Tenggara|
# |310|          6|       Emilio|     Apple Iphone 14|2023-04-28 22:49:43|     Belgium|    East Flanders|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|       state|
# +---+-----------+-------------+--------------------+-------------------+------------+------------+
# |311|          6|       Emilio|  Samsung Galaxy s22|2023-04-28 22:50:13|       Malta|       Mġarr|
# |312|         20|     JohnEric|Samsung Galaxy s2...|2023-04-28 22:50:43|       Nauru|Ewa District|
# +---+-----------+-------------+--------------------+-------------------+------------+------------+
#
# +---+-----------+-------------+----------------+-------------------+--------------+------------------+
# | id|customer_id|customer_name|product_searched|        search_date|  country_name|             state|
# +---+-----------+-------------+----------------+-------------------+--------------+------------------+
# |313|          2|     Marielys| Apple Iphone 14|2023-04-28 22:51:13|United Kingdom|      East Lothian|
# |314|         12|       Jowell|        Creatine|2023-04-28 22:51:43|United Kingdom|City of Portsmouth|
# +---+-----------+-------------+----------------+-------------------+--------------+------------------+
#
# +---+-----------+-------------+------------------+-------------------+-------------+--------------+
# | id|customer_id|customer_name|  product_searched|        search_date| country_name|         state|
# +---+-----------+-------------+------------------+-------------------+-------------+--------------+
# |315|         20|     JohnEric|Samsung Galaxy s22|2023-04-28 22:52:13|United States|South Carolina|
# |316|          3|      EmilyAn|   Ninja Air Frier|2023-04-28 22:52:43|  Philippines|      Guimaras|
# +---+-----------+-------------+------------------+-------------------+-------------+--------------+
# +---+-----------+-------------+----------------+-------------------+------------+-------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|              state|
# +---+-----------+-------------+----------------+-------------------+------------+-------------------+
# |317|         17|       Marcia|     Samsung Tab|2023-04-28 22:53:13|     Vietnam|          Khánh Hòa|
# |318|          2|     Marielys| Ninja Air Frier|2023-04-28 22:53:43|        Oman|Ash Sharqiyah North|
# +---+-----------+-------------+----------------+-------------------+------------+-------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+---------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|    state|
# +---+-----------+-------------+----------------+-------------------+------------+---------+
# |319|         14|       Mirtha| Apple Iphone 14|2023-04-28 22:54:13|     Vietnam|Quảng Trị|
# |320|         13|        Mario|      Air Jordan|2023-04-28 22:54:43|    Colombia|    Sucre|
# +---+-----------+-------------+----------------+-------------------+------------+---------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# |321|         20|     JohnEric|         Water Shoes|2023-04-28 22:55:13|      Bhutan|Wangdue Phodrang ...|
# |322|          7|         Emil|Samsung Galaxy s2...|2023-04-28 22:55:43|     Hungary|Borsod-Abaúj-Zemplén|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+--------------------+-------------------+---------------+--------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|   country_name|               state|
# +---+-----------+-------------+--------------------+-------------------+---------------+--------------------+
# |323|         16|       Marius|  Asus Gaming Laptop|2023-04-28 22:56:13|        Germany|              Berlin|
# |324|          1|       Johnny|Gildan Mens Assor...|2023-04-28 22:56:43|North Macedonia|Vevčani Municipality|
# +---+-----------+-------------+--------------------+-------------------+---------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+--------------+----------------+
# | id|customer_id|customer_name|product_searched|        search_date|  country_name|           state|
# +---+-----------+-------------+----------------+-------------------+--------------+----------------+
# |325|         18|       Johvay| Ninja Air Frier|2023-04-28 22:57:13|          Cuba|Holguín Province|
# |326|         19|    Johnathan|     Bed Pillows|2023-04-28 22:57:43|United Kingdom|      Inverclyde|
# +---+-----------+-------------+----------------+-------------------+--------------+----------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# |327|         13|        Mario| Apple Iphone 14|2023-04-28 22:58:13|    Malaysia|            Johor|
# |328|          5|        Maria| Ninja Air Frier|2023-04-28 22:58:43|      Guinea|Gaoual Prefecture|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+----------------+-------------------+--------------+--------------+
# | id|customer_id|customer_name|product_searched|        search_date|  country_name|         state|
# +---+-----------+-------------+----------------+-------------------+--------------+--------------+
# |329|         20|     JohnEric|      Fire Stick|2023-04-28 22:59:13|Czech Republic|         Kolín|
# |330|          3|      EmilyAn|     Samsung Tab|2023-04-28 22:59:43|       Morocco|Tanger-Assilah|
# +---+-----------+-------------+----------------+-------------------+--------------+--------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|              state|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# |331|          6|       Emilio|Gildan Mens Assor...|2023-04-28 23:00:13|      Guinea|    Fria Prefecture|
# |332|         20|     JohnEric|          Apple Ipad|2023-04-28 23:00:43|     Iceland|Northwestern Region|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+----------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|     state|
# +---+-----------+-------------+----------------+-------------------+------------+----------+
# |333|          1|       Johnny| Ninja Air Frier|2023-04-28 23:01:13|  Cape Verde|     Brava|
# |334|         14|       Mirtha|      Apple Ipad|2023-04-28 23:01:43|   Mauritius|Port Louis|
# +---+-----------+-------------+----------------+-------------------+------------+----------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# |335|          7|         Emil|         Bed Pillows|2023-04-28 23:02:13|      Greece|Kefalonia Prefecture|
# |336|         12|       Jowell|Workout Leggins f...|2023-04-28 23:02:43| Puerto Rico|              Gurabo|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|              state|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# |337|         14|       Mirtha|Samsung Galaxy s2...|2023-04-28 23:03:13|      Malawi|Nkhata Bay District|
# |338|         15|       Martha|     Ninja Air Frier|2023-04-28 23:03:43|  Azerbaijan|           Sumqayit|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+---------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|    state|
# +---+-----------+-------------+--------------------+-------------------+------------+---------+
# |339|         20|     JohnEric|Gildan Mens Assor...|2023-04-28 23:04:13|      France|Grand-Est|
# |340|         20|     JohnEric|          Fire Stick|2023-04-28 23:04:43|       Palau| Ngatpang|
# +---+-----------+-------------+--------------------+-------------------+------------+---------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|       state|
# +---+-----------+-------------+--------------------+-------------------+------------+------------+
# |341|         10|        Emona|Workout Leggins f...|2023-04-28 23:05:13| Puerto Rico|       Ponce|
# |342|         12|       Jowell|     Apple Iphone 14|2023-04-28 23:05:43|      France|Hautes-Alpes|
# +---+-----------+-------------+--------------------+-------------------+------------+------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+----------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|     state|
# +---+-----------+-------------+--------------------+-------------------+------------+----------+
# |343|         20|     JohnEric|         Samsung Tab|2023-04-28 23:06:13|       Ghana|Upper East|
# |344|         10|        Emona|Workout Leggins f...|2023-04-28 23:06:43|       Malta|    Qrendi|
# +---+-----------+-------------+--------------------+-------------------+------------+----------+
# +---+-----------+-------------+----------------+-------------------+------------+----------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|           state|
# +---+-----------+-------------+----------------+-------------------+------------+----------------+
# |345|         11|       Emilia| Ninja Air Frier|2023-04-28 23:07:13|    Ethiopia|       Dire Dawa|
# |346|         20|     JohnEric|     Samsung Tab|2023-04-28 23:07:43|    Bulgaria|Dobrich Province|
# +---+-----------+-------------+----------------+-------------------+------------+----------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|         state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------+
# |347|         14|       Mirtha|Workout Leggins f...|2023-04-28 23:08:13|    Tanzania|Zanzibar North|
# |348|         18|       Johvay|          Apple Ipad|2023-04-28 23:08:43|       Italy|       Trapani|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------+
#
# +---+-----------+-------------+------------------+-------------------+--------------------+---------------+
# | id|customer_id|customer_name|  product_searched|        search_date|        country_name|          state|
# +---+-----------+-------------+------------------+-------------------+--------------------+---------------+
# |349|          1|       Johnny|Asus Gaming Laptop|2023-04-28 23:09:13|Cote D'Ivoire (Iv...|Denguélé Region|
# |350|         16|       Marius|Samsung Galaxy s22|2023-04-28 23:09:43|              Brazil| Rio de Janeiro|
# +---+-----------+-------------+------------------+-------------------+--------------------+---------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|       state|
# +---+-----------+-------------+----------------+-------------------+------------+------------+
# |351|         10|        Emona|     Bed Pillows|2023-04-28 23:10:13|    Cambodia|Kampong Thom|
# |352|         14|       Mirtha|      Apple Ipad|2023-04-28 23:10:43|    Maldives|   Raa Atoll|
# +---+-----------+-------------+----------------+-------------------+------------+------------+
#
# +---+-----------+-------------+------------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+------------------+-------------------+------------+--------------------+
# |353|         12|       Jowell|          Creatine|2023-04-28 23:11:13|  Bangladesh|    Barisal Division|
# |354|         16|       Marius|Samsung Galaxy s22|2023-04-28 23:11:43|     Ukraine|Ivano-Frankivska ...|
# +---+-----------+-------------+------------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+----------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|     state|
# +---+-----------+-------------+----------------+-------------------+------------+----------+
# |355|          6|       Emilio|      Apple Ipad|2023-04-28 23:12:13|       Spain| Salamanca|
# |356|          8|      Maryina|     Samsung Tab|2023-04-28 23:12:43|   Indonesia|Jawa Barat|
# +---+-----------+-------------+----------------+-------------------+------------+----------+
